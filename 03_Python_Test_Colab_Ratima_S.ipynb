# %% [markdown]
# <a href="https://colab.research.google.com/github/ratimayy/shopee/blob/main/03_Python_Test_Colab_Ratima_S.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
exchange_rate = pd.read_csv('https://raw.githubusercontent.com/ratimayy/shopee/main/exchange_rate.csv')
exchange_rate
# Out:
#    grass_region currency  exchange_rate
# 0            SG      SGD       1.362050
# 1            TW      TWD      32.242500
# 2            MY      MYR       4.686750
# 3            ID      IDR   15480.500000
# 4            PH      PHP      56.584000
# 5            TH      THB      36.486500
# 6            VN      VND   24327.500000
# 7            BR      BRL       5.033400
# 8            CN      CNY       7.298000
# 9            HK      HKD       7.828700
# 10           KR      KRW    1348.025000
# 11          AUS      AUD       1.543805
# 12           EU      EUR       0.944242
# 13           UK      GBP       0.816693
# 14           JP      JPY     148.765000
# 15           MX      MXN      17.431550
# 16           CO      COP    4077.200000
# 17           IN      INR      83.060000
# 18           CL      CLP     908.360000
# 19           TR      TRY      27.467600
# 20           PL      PLN       4.377150
# 21           ES      EUR       0.944242
# ...

# %%
platform_number = pd.read_csv('https://raw.githubusercontent.com/ratimayy/shopee/main/platform_number.csv')
platform_number
# Out:
#   region  platform order  platform_gmv_usd
# 0     ID      1553364.13      2.438838e+08
# 1     MY       333184.27      7.341684e+07
# 2     PH       392687.73      7.538330e+07
# 3     SG       526181.77      9.917030e+07
# 4     TH      1018358.54      1.734009e+08
# 5     VN       413006.15      7.454916e+07

# %%
# platform_number['platform order'] = platform_number['platform order'].str.replace(',', '').astype(float)
# platform_number['platform_gmv_usd'] = platform_number['platform_gmv_usd'].str.replace(',', '').astype(float)

# %%
platform_number.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6 entries, 0 to 5
# Data columns (total 3 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   region            6 non-null      object
#  1   platform order    6 non-null      float64
#  2   platform_gmv_usd  6 non-null      float64
# dtypes: float64(2), object(1)
# memory usage: 272.0+ bytes

# %%
pricing_project_dataset = pd.read_csv('https://raw.githubusercontent.com/ratimayy/shopee/main/pricing_project_dataset.csv')
pricing_project_dataset
# Out:
#       grass_region category_group     seller_type  shopee_item_id  \
# 0               ID    Electronics  Long Tail (LT)      5646734211
# 1               SG           FMCG  Long Tail (LT)      3735125711
# 2               TH    Electronics        Non-Mall      2579813608
# 3               PH           FMCG  Long Tail (LT)      8699492214
# 4               TH           FMCG  Long Tail (LT)      4815010572
# ...            ...            ...             ...             ...
# 20994           SG      Lifestyle  Long Tail (LT)      9056263816
# 20995           ID    Electronics    Cross Border      2229891587
# 20996           TH      Lifestyle            Mall      5857526694
# 20997           SG        Fashion            Mall      7785760835
# 20998           ID      Lifestyle    Cross Border      2760118977
#
#        shopee_model_id  competitor_item_id  competitor_model_id  \
# 0           3953474697          9153508336            992466002
# ...

# %%
pricing_project_dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20999 entries, 0 to 20998
# Data columns (total 13 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   grass_region                         20999 non-null  object
#  1   category_group                       20999 non-null  object
#  2   seller_type                          20999 non-null  object
#  3   shopee_item_id                       20999 non-null  int64
#  4   shopee_model_id                      20999 non-null  int64
#  5   competitor_item_id                   20999 non-null  int64
#  6   competitor_model_id                  20999 non-null  int64
#  7   shopee_model_price_usd               20999 non-null  float64
#  8   shopee_model_price                   20999 non-null  float64
#  9   competitor_model_price               20999 non-null  float64
#  10  shopee_gmv_usd                       20999 non-null  float64
# ...

# %%
#question 2

# Define priority dictionary
priority = {'Shopee < CPT': 0, 'Shopee = CPT': 1, 'Shopee > CPT': 2}

# Add Priority column based on Platform
pricing_project_dataset['Priority'] = pricing_project_dataset['shopee_model_competitiveness_status'].map(priority)

# Sort DataFrame by Priority
df_sorted = pricing_project_dataset.sort_values(by='Priority')

# Drop Priority column if needed
df_sorted.drop('Priority', axis=1, inplace=True)

print(df_sorted)
# Out:
#       grass_region category_group     seller_type  shopee_item_id  \
# 10499           ID      Lifestyle  Long Tail (LT)       376413509
# 11650           MY    Electronics            Mall      2865107126
# 11652           MY      Lifestyle        Non-Mall      3112647982
# 11655           ID      Lifestyle        Non-Mall      5973994675
# 11658           ID      Lifestyle            Mall      9134585713
# ...            ...            ...             ...             ...
# 3662            TH           FMCG            Mall      4181399028
# 8726            TH        Fashion  Long Tail (LT)      7496093942
# 13624           TH    Electronics  Long Tail (LT)      3845292035
# 13616           ID        Fashion    Cross Border      1765323904
# 0               ID    Electronics  Long Tail (LT)      5646734211
#
#        shopee_model_id  competitor_item_id  competitor_model_id  \
# 10499       3784867317           980311365           4613015598
# ...

# %%
grouped_data = pricing_project_dataset.groupby('grass_region')['shopee_gmv_usd'].sum().reset_index()

# Sorting the grouped data by shopee_gmv_usd
grouped_data = grouped_data.sort_values(by='shopee_gmv_usd',ascending=False)

# Creating the bar chart using Plotly Express
fig = px.bar(grouped_data, x='grass_region', y='shopee_gmv_usd', labels={'shopee_gmv_usd': 'Sum of Shopee Model Price', 'grass_region': 'Grass Region'})
fig.update_layout(title='Sum of shopee_gmv_usd by Grass Region')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
df = pd.DataFrame(platform_number)

# Plotting the pie chart using Plotly Express
fig = px.pie(df, values='platform order', names='region', title='Platform Order per Region')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# Google slide for question number 4: https://docs.google.com/presentation/d/1i0riagTUt2VOQs3LEgGm5eo48Ly_wwOxEP6vOvPcUig/edit#slide=id.p
